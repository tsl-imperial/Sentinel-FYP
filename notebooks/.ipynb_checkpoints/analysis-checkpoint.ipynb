# %%
import ee
ee.Initialize(project="sentinel-487715")

import geopandas as gpd

roads = gpd.read_file("/Users/miranda/Documents/GitHub/Sentinel-FYP/data/ghana-260216-free.shp/gis_osm_roads_free_1.shp")
roads = roads.to_crs("EPSG:4326")
roads.head()

from shapely.geometry import box

aoi = box(-0.6, 5.3, 0.2, 5.9)  # Accra bbox
roads_aoi = roads[roads.intersects(aoi)].copy()
len(roads_aoi)
# Out:
# EE OK

# %%
import datetime as dt

ghana_bbox = ee.Geometry.Rectangle([-0.6, 5.3, 0.2, 5.9])
s2 = (ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
      .filterBounds(ghana_bbox)
      .filterDate("2023-01-01", "2023-12-31")
      .filter(ee.Filter.lt("CLOUDY_PIXEL_PERCENTAGE", 20))
      .select(["B2","B3","B4","B8","B11","B12"]))

composite = s2.median()

from shapely.geometry import LineString
import pandas as pd

def midpoint_of_linestring(ls: LineString):
    return ls.interpolate(0.5, normalized=True)

# take small sample for testing
sample = roads_aoi.sample(50, random_state=0).copy()
sample["midpt"] = sample.geometry.apply(midpoint_of_linestring)

# build EE FeatureCollection of points
features = []
for i, pt in enumerate(sample["midpt"]):
    features.append(ee.Feature(ee.Geometry.Point([pt.x, pt.y]), {"id": i}))
fc = ee.FeatureCollection(features)

# sample the composite at points
sampled = composite.sampleRegions(collection=fc, scale=10, geometries=True)
df = pd.DataFrame(sampled.getInfo()["features"])
# flatten properties
rows = [f["properties"] for f in sampled.getInfo()["features"]]
df = pd.DataFrame(rows)
df.head()
# Out:
#       B11     B12      B2      B3    B4      B8  id
# 0  2767.5  2629.5  1014.0  1323.0  1707  2126.0   0
# 1  3165.5  2844.5   857.0  1174.0  1481  2367.0   1
# 2  3562.0  2939.5   700.5  1087.0  1404  2479.0   2
# 3  2670.0  2517.0  1052.0  1280.0  1452  1938.0   3
# 4  3130.0  2565.0  1152.0  1460.0  1662  2576.0   4

# %%
import geemap

m = geemap.Map(center=[5.6, -0.2], zoom=10)
m.add_basemap("HYBRID")

# your Sentinel layer (assuming composite is defined)
m.addLayer(composite, {"bands":["B4","B3","B2"], "min":0, "max":3000}, "S2 True Color")

# add roads as vector overlay
m.add_gdf(roads_aoi, layer_name="OSM Roads (shapefile)")

m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[5.6, -0.2], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright', t…

# %%
# easiest: reproject AOI roads to a metric CRS for Ghana
roads_m = roads_aoi.to_crs("EPSG:32630")  # UTM zone 30N (covers Ghana well)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from shapely.geometry import LineString
import geopandas as gpd
import numpy as np

def split_line(line, segment_length=200):
    """
    Split a LineString into equal-length segments (in meters).
    """
    segments = []
    total_length = line.length

    # Create split points every segment_length
    distances = np.arange(0, total_length, segment_length)

    for start in distances:
        end = min(start + segment_length, total_length)
        segment = line.interpolate(start), line.interpolate(end)
        segment = LineString(segment)
        segments.append(segment)

    return segments


# Apply splitting to all roads
all_segments = []

for idx, row in roads_m.iterrows():
    geom = row.geometry
    
    if geom.geom_type == "LineString":
        segments = split_line(geom, segment_length=200)
        
        for seg in segments:
            all_segments.append({
                "geometry": seg,
                "fclass": row.get("fclass", None)
            })

# Create new GeoDataFrame of segments
segments_gdf = gpd.GeoDataFrame(all_segments, crs=roads_m.crs)

print("Number of road segments:", len(segments_gdf))
segments_gdf.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Number of road segments: 186010
#                                             geometry        fclass
# 0  LINESTRING (813332.18 620680.284, 813332.18 62...  unclassified
# 1  LINESTRING (812113.032 621062.316, 811915.646 ...   residential
# 2  LINESTRING (811915.646 621045.79, 811800.938 6...   residential
# 3  LINESTRING (812935.075 620350.037, 813134.744 ...      tertiary
# 4  LINESTRING (813134.744 620360.985, 813171.342 ...      tertiary

# %%
segments_wgs = segments_gdf.to_crs("EPSG:4326")
segments_wgs.head()

print("Number of road segments:", len(segments_gdf))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Number of road segments: 186010
